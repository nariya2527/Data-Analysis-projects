# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Students = ['A','B','C','D','E']
marks = [99,75,85,98,78]

# %%
# Bar chart
plt.bar(Students,Subjects,label='Maths Marks')
plt.title('Students Data')
plt.xlabel('subjects')
plt.ylabel('Students')
plt.show()

# line graph
plt.plot(Students,Subjects,color='skyblue',marker='o',linestyle='--')
plt.title('Comparison Between 3 Subjects')
plt.xlabel('subjects')
plt.ylabel('Students')
plt.show()

# pie chart
plt.pie(marks,labels=Subjects,autopct='%1.1f%%')
plt.title('Maths Students Marks')
plt.show()

# scatter plot
plt.scatter(Students,Subjects,color='red')
plt.title('Maths vs Science Marks')
plt.show()

# subplot
plt.figure(figsize=(8,4))

# First subplot (1 rows,2 columns,1 position)
plt.subplot(1,2,1)
plt.plot(Students,Subjects)
plt.title('Maths Marks')

# Second subplot
plt.subplot(1,2,2)
plt.bar(Students,Subjects)
plt.title('Science Marks')
plt.show()
